# %%
import pandas as pd

# %%
df=pd.read_csv('../dataset/orders.csv')
df
# Out:
#       Order Id  Order Date       Ship Mode    Segment        Country  \
# 0            1  01-03-2023    Second Class   Consumer  United States
# 1            2  15-08-2023    Second Class   Consumer  United States
# 2            3  10-01-2023    Second Class  Corporate  United States
# 3            4  18-06-2022  Standard Class   Consumer  United States
# 4            5  13-07-2022  Standard Class   Consumer  United States
# ...        ...         ...             ...        ...            ...
# 9989      9990  18-02-2023    Second Class   Consumer  United States
# 9990      9991  17-03-2023  Standard Class   Consumer  United States
# 9991      9992  07-08-2022  Standard Class   Consumer  United States
# 9992      9993  19-11-2022  Standard Class   Consumer  United States
# 9993      9994  17-07-2022    Second Class   Consumer  United States
#
#                  City       State  Postal Code Region         Category  \
# 0           Henderson    Kentucky        42420  South        Furniture
# 1           Henderson    Kentucky        42420  South        Furniture
# 2         Los Angeles  California        90036   West  Office Supplies
# 3     Fort Lauderdale     Florida        33311  South        Furniture
# 4     Fort Lauderdale     Florida        33311  South  Office Supplies
# ...               ...         ...          ...    ...              ...
# 9989            Miami     Florida        33180  South        Furniture
# 9990       Costa Mesa  California        92627   West        Furniture
# 9991       Costa Mesa  California        92627   West       Technology
# 9992       Costa Mesa  California        92627   West  Office Supplies
# 9993      Westminster  California        92683   West  Office Supplies
#
#      Sub Category       Product Id  cost price  List Price  Quantity  \
# 0       Bookcases  FUR-BO-10001798         240         260         2
# 1          Chairs  FUR-CH-10000454         600         730         3
# 2          Labels  OFF-LA-10000240          10          10         2
# 3          Tables  FUR-TA-10000577         780         960         5
# 4         Storage  OFF-ST-10000760          20          20         2
# ...           ...              ...         ...         ...       ...
# 9989  Furnishings  FUR-FU-10001889          30          30         3
# 9990  Furnishings  FUR-FU-10000747          70          90         2
# 9991       Phones  TEC-PH-10003645         220         260         2
# 9992        Paper  OFF-PA-10004041          30          30         4
# 9993   Appliances  OFF-AP-10002684         210         240         2
#
#       Discount Percent
# 0                    2
# 1                    3
# 2                    5
# 3                    2
# 4                    5
# ...                ...
# 9989                 4
# 9990                 4
# 9991                 2
# 9992                 3
# 9993                 3
#
# [9994 rows x 16 columns]

# %%
df.rename(columns={
    'Order Id': 'order_id',
    'Order Date': 'order_date',
    'Ship Mode': 'ship_mode',
    'Segment': 'segment',
    'Country': 'country',
    'City': 'city',
    'State': 'state',
    'Postal Code': 'postal_code',
    'Region': 'region',
    'Category': 'category',
    'Sub Category': 'sub_category',
    'Product Id': 'product_id',
    'cost price': 'cost_price',
    'List Price': 'list_price',
    'Quantity': 'quantity',
    'Discount Percent': 'discount_percent'
}, inplace=True)

# %%
df = df.set_index("order_id")
df.head()
# Out:
#           order_date       ship_mode    segment        country  \
# order_id
# 1         01-03-2023    Second Class   Consumer  United States
# 2         15-08-2023    Second Class   Consumer  United States
# 3         10-01-2023    Second Class  Corporate  United States
# 4         18-06-2022  Standard Class   Consumer  United States
# 5         13-07-2022  Standard Class   Consumer  United States
#
#                      city       state  postal_code region         category  \
# order_id
# 1               Henderson    Kentucky        42420  South        Furniture
# 2               Henderson    Kentucky        42420  South        Furniture
# 3             Los Angeles  California        90036   West  Office Supplies
# 4         Fort Lauderdale     Florida        33311  South        Furniture
# 5         Fort Lauderdale     Florida        33311  South  Office Supplies
#
#          sub_category       product_id  cost_price  list_price  quantity  \
# order_id
# 1           Bookcases  FUR-BO-10001798         240         260         2
# 2              Chairs  FUR-CH-10000454         600         730         3
# 3              Labels  OFF-LA-10000240          10          10         2
# 4              Tables  FUR-TA-10000577         780         960         5
# 5             Storage  OFF-ST-10000760          20          20         2
#
#           discount_percent
# order_id
# 1                        2
# 2                        3
# 3                        5
# 4                        2
# 5                        5

# %%
df.isnull().sum()
# Out:
# order_date          0
# ship_mode           1
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# sub_category        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# dtype: int64

# %%
df = df.dropna(subset=["ship_mode"])

# %%
df.isnull().sum()
# Out:
# order_date          0
# ship_mode           0
# segment             0
# country             0
# city                0
# state               0
# postal_code         0
# region              0
# category            0
# sub_category        0
# product_id          0
# cost_price          0
# list_price          0
# quantity            0
# discount_percent    0
# dtype: int64

# %%
df.describe()
# Out:
#         postal_code    cost_price    list_price     quantity  discount_percent
# count   9993.000000   9993.000000   9993.000000  9993.000000       9993.000000
# mean   55192.137696    201.195837    229.763835     3.789853          3.483939
# std    32064.815951    537.769763    623.276635     2.225046          1.114164
# min     1040.000000      0.000000      0.000000     1.000000          2.000000
# 25%    23223.000000     20.000000     20.000000     2.000000          2.000000
# 50%    56560.000000     50.000000     50.000000     3.000000          3.000000
# 75%    90008.000000    180.000000    210.000000     5.000000          4.000000
# max    99301.000000  18110.000000  22640.000000    14.000000          5.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9993 entries, 1 to 9994
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_date        9993 non-null   object
#  1   ship_mode         9993 non-null   object
#  2   segment           9993 non-null   object
#  3   country           9993 non-null   object
#  4   city              9993 non-null   object
#  5   state             9993 non-null   object
#  6   postal_code       9993 non-null   int64
#  7   region            9993 non-null   object
#  8   category          9993 non-null   object
#  9   sub_category      9993 non-null   object
#  10  product_id        9993 non-null   object
#  11  cost_price        9993 non-null   int64
#  12  list_price        9993 non-null   int64
#  13  quantity          9993 non-null   int64
#  14  discount_percent  9993 non-null   int64
# dtypes: int64(5), object(10)
# memory usage: 1.2+ MB

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df['sub_category'].unique()
# Out:
# array(['Bookcases', 'Chairs', 'Labels', 'Tables', 'Storage',
#        'Furnishings', 'Art', 'Phones', 'Binders', 'Appliances', 'Paper',
#        'Accessories', 'Envelopes', 'Fasteners', 'Supplies', 'Machines',
#        'Copiers'], dtype=object)

# %%
df['ship_mode'].unique()
# Out:
# array(['Second Class', 'Standard Class', 'Not Available', 'unknown',
#        'First Class', 'Same Day'], dtype=object)

# %%
df['final_customer_price']=(df['list_price']*df['quantity'])*(1-(df['discount_percent']/100))

# %%
df['profit']=df['final_customer_price']-(df['cost_price']*df['quantity'])

# %%
df
# Out:
#           order_date       ship_mode    segment        country  \
# order_id
# 1         01-03-2023    Second Class   Consumer  United States
# 2         15-08-2023    Second Class   Consumer  United States
# 3         10-01-2023    Second Class  Corporate  United States
# 4         18-06-2022  Standard Class   Consumer  United States
# 5         13-07-2022  Standard Class   Consumer  United States
# ...              ...             ...        ...            ...
# 9990      18-02-2023    Second Class   Consumer  United States
# 9991      17-03-2023  Standard Class   Consumer  United States
# 9992      07-08-2022  Standard Class   Consumer  United States
# 9993      19-11-2022  Standard Class   Consumer  United States
# 9994      17-07-2022    Second Class   Consumer  United States
#
#                      city       state  postal_code region         category  \
# order_id
# 1               Henderson    Kentucky        42420  South        Furniture
# 2               Henderson    Kentucky        42420  South        Furniture
# 3             Los Angeles  California        90036   West  Office Supplies
# 4         Fort Lauderdale     Florida        33311  South        Furniture
# 5         Fort Lauderdale     Florida        33311  South  Office Supplies
# ...                   ...         ...          ...    ...              ...
# 9990                Miami     Florida        33180  South        Furniture
# 9991           Costa Mesa  California        92627   West        Furniture
# 9992           Costa Mesa  California        92627   West       Technology
# 9993           Costa Mesa  California        92627   West  Office Supplies
# 9994          Westminster  California        92683   West  Office Supplies
#
#          sub_category       product_id  cost_price  list_price  quantity  \
# order_id
# 1           Bookcases  FUR-BO-10001798         240         260         2
# 2              Chairs  FUR-CH-10000454         600         730         3
# 3              Labels  OFF-LA-10000240          10          10         2
# 4              Tables  FUR-TA-10000577         780         960         5
# 5             Storage  OFF-ST-10000760          20          20         2
# ...               ...              ...         ...         ...       ...
# 9990      Furnishings  FUR-FU-10001889          30          30         3
# 9991      Furnishings  FUR-FU-10000747          70          90         2
# 9992           Phones  TEC-PH-10003645         220         260         2
# 9993            Paper  OFF-PA-10004041          30          30         4
# 9994       Appliances  OFF-AP-10002684         210         240         2
#
#           discount_percent  final_customer_price  profit
# order_id
# 1                        2                 509.6    29.6
# 2                        3                2124.3   324.3
# 3                        5                  19.0    -1.0
# 4                        2                4704.0   804.0
# 5                        5                  38.0    -2.0
# ...                    ...                   ...     ...
# 9990                     4                  86.4    -3.6
# 9991                     4                 172.8    32.8
# 9992                     2                 509.6    69.6
# 9993                     3                 116.4    -3.6
# 9994                     3                 465.6    45.6
#
# [9993 rows x 17 columns]

# %%
df.to_csv('../dataset/orders.csv')

# %%
df['profit'].sum()
# Out:
# np.float64(1039916.2)

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
monthly_profit=df.groupby(df['order_date'].dt.to_period('M'))['profit'].sum().reset_index(name='monthly_price')
monthly_profit
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df['order_date'] = pd.to_datetime(df['order_date'])
#       2 monthly_profit=df.groupby(df['order_date'].dt.to_period('M'))['profit'].sum().reset_index(name='monthly_price')
#       3 monthly_profit
#
# File c:\Users\Princia\Desktop\Project\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:1072, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1070         result = arg.map(cache_array)
#    1071     else:
# -> 1072         values = convert_listlike(arg._values, format)
#    1073         result = arg._constructor(values, index=arg.index, name=arg.name)
#    1074 elif isinstance(arg, (ABCDataFrame, abc.MutableMapping)):
#
# File c:\Users\Princia\Desktop\Project\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:435, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     433 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     434 if format is not None and format != "mixed":
# --> 435     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     437 result, tz_parsed = objects_to_datetime64(
#     438     arg,
#     439     dayfirst=dayfirst,
#    (...)    443     allow_object=True,
#     444 )
#     446 if tz_parsed is not None:
#     447     # We can take a shortcut since the datetime64 numpy array
#     448     # is in UTC
#
# File c:\Users\Princia\Desktop\Project\.venv\Lib\site-packages\pandas\core\tools\datetimes.py:469, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     458 def _array_strptime_with_fallback(
#     459     arg,
#     460     name,
#    (...)    464     errors: str,
#     465 ) -> Index:
#     466     """
#     467     Call array_strptime, with fallback behavior depending on 'errors'.
#     468     """
# --> 469     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     470     if tz_out is not None:
#     471         unit = np.datetime_data(result.dtype)[0]
#
# File pandas/_libs/tslibs/strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File pandas/_libs/tslibs/strptime.pyx:583, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: time data "15-08-2023" doesn't match format "%m-%d-%Y", at position 1. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
monthly_profit.to_csv('../dataset/monthly_profit.csv')

# %%
products=df[['product_id','category','sub_category','cost_price','list_price']]
products.reset_index(inplace=True)

# %% [markdown]
# order_id column appears because it was set as index column in original  df.

# %%
products
# Out:
#       order_id       product_id         category sub_category  cost_price  \
# 0            1  FUR-BO-10001798        Furniture    Bookcases         240
# 1            2  FUR-CH-10000454        Furniture       Chairs         600
# 2            3  OFF-LA-10000240  Office Supplies       Labels          10
# 3            4  FUR-TA-10000577        Furniture       Tables         780
# 4            5  OFF-ST-10000760  Office Supplies      Storage          20
# ...        ...              ...              ...          ...         ...
# 9988      9990  FUR-FU-10001889        Furniture  Furnishings          30
# 9989      9991  FUR-FU-10000747        Furniture  Furnishings          70
# 9990      9992  TEC-PH-10003645       Technology       Phones         220
# 9991      9993  OFF-PA-10004041  Office Supplies        Paper          30
# 9992      9994  OFF-AP-10002684  Office Supplies   Appliances         210
#
#       list_price
# 0            260
# 1            730
# 2             10
# 3            960
# 4             20
# ...          ...
# 9988          30
# 9989          90
# 9990         260
# 9991          30
# 9992         240
#
# [9993 rows x 6 columns]

# %%
products.drop(columns=['order_id'],inplace=True)
products
# Out:
# C:\Users\Princia\AppData\Local\Temp\ipykernel_6616\1179262996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products.drop(columns=['order_id'],inplace=True)
#            product_id         category sub_category  cost_price  list_price
# 0     FUR-BO-10001798        Furniture    Bookcases         240         260
# 1     FUR-CH-10000454        Furniture       Chairs         600         730
# 2     OFF-LA-10000240  Office Supplies       Labels          10          10
# 3     FUR-TA-10000577        Furniture       Tables         780         960
# 4     OFF-ST-10000760  Office Supplies      Storage          20          20
# ...               ...              ...          ...         ...         ...
# 9988  FUR-FU-10001889        Furniture  Furnishings          30          30
# 9989  FUR-FU-10000747        Furniture  Furnishings          70          90
# 9990  TEC-PH-10003645       Technology       Phones         220         260
# 9991  OFF-PA-10004041  Office Supplies        Paper          30          30
# 9992  OFF-AP-10002684  Office Supplies   Appliances         210         240
#
# [9993 rows x 5 columns]

# %%
products.duplicated().sum()
# Out:
# np.int64(2284)

# %%
products.nunique()
# Out:
# product_id      1862
# category           3
# sub_category      17
# cost_price       280
# list_price       289
# dtype: int64

# %%
duplicate=products.duplicated().sum()
print(duplicate)
# Out:
# 2284

# %%
products.drop_duplicates(inplace=True)
# Out:
# C:\Users\Princia\AppData\Local\Temp\ipykernel_6616\4277409331.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   products.drop_duplicates(inplace=True)

# %%
products
# Out:
#            product_id         category sub_category  cost_price  list_price
# 0     FUR-BO-10001798        Furniture    Bookcases         240         260
# 1     FUR-CH-10000454        Furniture       Chairs         600         730
# 2     OFF-LA-10000240  Office Supplies       Labels          10          10
# 3     FUR-TA-10000577        Furniture       Tables         780         960
# 4     OFF-ST-10000760  Office Supplies      Storage          20          20
# ...               ...              ...          ...         ...         ...
# 9986  TEC-AC-10001539       Technology  Accessories          80          80
# 9987  TEC-PH-10004006       Technology       Phones         180         210
# 9989  FUR-FU-10000747        Furniture  Furnishings          70          90
# 9990  TEC-PH-10003645       Technology       Phones         220         260
# 9992  OFF-AP-10002684  Office Supplies   Appliances         210         240
#
# [7709 rows x 5 columns]

# %%
products=products.reset_index()

# %%
products
# Out:
#       index       product_id         category sub_category  cost_price  \
# 0         0  FUR-BO-10001798        Furniture    Bookcases         240
# 1         1  FUR-CH-10000454        Furniture       Chairs         600
# 2         2  OFF-LA-10000240  Office Supplies       Labels          10
# 3         3  FUR-TA-10000577        Furniture       Tables         780
# 4         4  OFF-ST-10000760  Office Supplies      Storage          20
# ...     ...              ...              ...          ...         ...
# 7704   9986  TEC-AC-10001539       Technology  Accessories          80
# 7705   9987  TEC-PH-10004006       Technology       Phones         180
# 7706   9989  FUR-FU-10000747        Furniture  Furnishings          70
# 7707   9990  TEC-PH-10003645       Technology       Phones         220
# 7708   9992  OFF-AP-10002684  Office Supplies   Appliances         210
#
#       list_price
# 0            260
# 1            730
# 2             10
# 3            960
# 4             20
# ...          ...
# 7704          80
# 7705         210
# 7706          90
# 7707         260
# 7708         240
#
# [7709 rows x 6 columns]

# %%
products.to_csv('../dataset/products.csv')

# %%
order_location=df[['country','city','state','postal_code','region']]
order_location=order_location.reset_index()
order_location=order_location.drop(columns=['order_id'])

# %%
order_location
# Out:
#             country             city       state  postal_code region
# 0     United States        Henderson    Kentucky        42420  South
# 1     United States        Henderson    Kentucky        42420  South
# 2     United States      Los Angeles  California        90036   West
# 3     United States  Fort Lauderdale     Florida        33311  South
# 4     United States  Fort Lauderdale     Florida        33311  South
# ...             ...              ...         ...          ...    ...
# 9988  United States            Miami     Florida        33180  South
# 9989  United States       Costa Mesa  California        92627   West
# 9990  United States       Costa Mesa  California        92627   West
# 9991  United States       Costa Mesa  California        92627   West
# 9992  United States      Westminster  California        92683   West
#
# [9993 rows x 5 columns]

# %%
order_location.duplicated().sum()
# Out:
# np.int64(9361)

# %%
order_location=order_location.drop_duplicates()

# %%
order_location['postal_code'].nunique()
# Out:
# 631

# %%
order_location
# Out:
#             country             city           state  postal_code   region
# 0     United States        Henderson        Kentucky        42420    South
# 2     United States      Los Angeles      California        90036     West
# 3     United States  Fort Lauderdale         Florida        33311    South
# 5     United States      Los Angeles      California        90032     West
# 12    United States          Concord  North Carolina        28027    South
# ...             ...              ...             ...          ...      ...
# 9759  United States       Springdale        Arkansas        72762    South
# 9800  United States             Lodi      California        95240     West
# 9833  United States         La Porte           Texas        77571  Central
# 9867  United States            Mason            Ohio        45040     East
# 9880  United States        Woodstock         Georgia        30188    South
#
# [632 rows x 5 columns]

# %%
order_location['postal_code'].duplicated().sum()
# Out:
# np.int64(1)

# %%
order_location = order_location.drop_duplicates(subset=['postal_code'])

# %%
order_location['postal_code'].duplicated().sum()
# Out:
# np.int64(0)

# %%
order_location
# Out:
#             country             city           state  postal_code   region
# 0     United States        Henderson        Kentucky        42420    South
# 2     United States      Los Angeles      California        90036     West
# 3     United States  Fort Lauderdale         Florida        33311    South
# 5     United States      Los Angeles      California        90032     West
# 12    United States          Concord  North Carolina        28027    South
# ...             ...              ...             ...          ...      ...
# 9759  United States       Springdale        Arkansas        72762    South
# 9800  United States             Lodi      California        95240     West
# 9833  United States         La Porte           Texas        77571  Central
# 9867  United States            Mason            Ohio        45040     East
# 9880  United States        Woodstock         Georgia        30188    South
#
# [631 rows x 5 columns]

# %%
order_location=order_location.reset_index()

# %%
order_location.to_csv('../dataset/order_location.csv')

# %%
df
# Out:
#          order_date       ship_mode    segment        country  \
# order_id
# 1        2023-03-01    Second Class   Consumer  United States
# 2        2023-08-15    Second Class   Consumer  United States
# 3        2023-01-10    Second Class  Corporate  United States
# 4        2022-06-18  Standard Class   Consumer  United States
# 5        2022-07-13  Standard Class   Consumer  United States
# ...             ...             ...        ...            ...
# 9990     2023-02-18    Second Class   Consumer  United States
# 9991     2023-03-17  Standard Class   Consumer  United States
# 9992     2022-08-07  Standard Class   Consumer  United States
# 9993     2022-11-19  Standard Class   Consumer  United States
# 9994     2022-07-17    Second Class   Consumer  United States
#
#                      city       state  postal_code region         category  \
# order_id
# 1               Henderson    Kentucky        42420  South        Furniture
# 2               Henderson    Kentucky        42420  South        Furniture
# 3             Los Angeles  California        90036   West  Office Supplies
# 4         Fort Lauderdale     Florida        33311  South        Furniture
# 5         Fort Lauderdale     Florida        33311  South  Office Supplies
# ...                   ...         ...          ...    ...              ...
# 9990                Miami     Florida        33180  South        Furniture
# 9991           Costa Mesa  California        92627   West        Furniture
# 9992           Costa Mesa  California        92627   West       Technology
# 9993           Costa Mesa  California        92627   West  Office Supplies
# 9994          Westminster  California        92683   West  Office Supplies
#
#          sub_category       product_id  cost_price  list_price  quantity  \
# order_id
# 1           Bookcases  FUR-BO-10001798         240         260         2
# 2              Chairs  FUR-CH-10000454         600         730         3
# 3              Labels  OFF-LA-10000240          10          10         2
# 4              Tables  FUR-TA-10000577         780         960         5
# 5             Storage  OFF-ST-10000760          20          20         2
# ...               ...              ...         ...         ...       ...
# 9990      Furnishings  FUR-FU-10001889          30          30         3
# 9991      Furnishings  FUR-FU-10000747          70          90         2
# 9992           Phones  TEC-PH-10003645         220         260         2
# 9993            Paper  OFF-PA-10004041          30          30         4
# 9994       Appliances  OFF-AP-10002684         210         240         2
#
#           discount_percent  final_customer_price  profit
# order_id
# 1                        2                 509.6    29.6
# 2                        3                2124.3   324.3
# 3                        5                  19.0    -1.0
# 4                        2                4704.0   804.0
# 5                        5                  38.0    -2.0
# ...                    ...                   ...     ...
# 9990                     4                  86.4    -3.6
# 9991                     4                 172.8    32.8
# 9992                     2                 509.6    69.6
# 9993                     3                 116.4    -3.6
# 9994                     3                 465.6    45.6
#
# [9993 rows x 17 columns]
